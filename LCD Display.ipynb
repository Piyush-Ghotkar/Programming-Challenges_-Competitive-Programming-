# %%
def fun1(matrix,lines,scol):
    m=1
    n=scol+2+(lines-1)
    
    for i in range(lines):
        matrix[m][n]='|'
        m+=1
    m+=1
    for i in range(lines):
        matrix[m][n]='|'
        m+=1

def fun2(matrix,lines,scol):
    m=0
    n=scol+1
    
    for i in range(0,3):
        n=scol+1
        for j in range(lines):
            matrix[m][n]='-'
            n+=1
        m+=lines+1
        
    m=0
    n=scol+2+(lines-1)
    for i in range(lines):
        m+=1
        matrix[m][n]='|'
        
    m=0+2+(lines-1)
    n=scol
    for i in range(lines):
        m+=1
        matrix[m][n]='|'
        
def fun3(matrix,lines,scol):
    m=0
    n=scol+1
    
    for i in range(0,3):
        n=scol+1
        for j in range(lines):
            matrix[m][n]='-'
            n+=1
        m+=lines+1
        
    m=0
    n=scol+2+(lines-1)
    for i in range(lines):
        m+=1
        matrix[m][n]='|'
    
    m=0+2+(lines-1)
    n=scol+2+(lines-1)
    for i in range(lines):
        m+=1
        matrix[m][n]='|'

def fun4(matrix,lines,scol):
    m=0
    n=scol+2+(lines-1)
    for i in range(lines):
        m+=1
        matrix[m][n]='|'
    
    m=0+2+(lines-1)
    n=scol+2+(lines-1)
    for i in range(lines):
        m+=1
        matrix[m][n]='|'
        
    m=0
    n=scol
    for i in range(lines):
        m+=1
        matrix[m][n]='|'
        
    m=0+lines+1
    n=scol+1
    for i in range(lines):
        matrix[m][n]='-'
        n+=1
        
def fun5(matrix,lines,scol):
    m=0
    n=scol+1
    
    for i in range(0,3):
        n=scol+1
        for j in range(lines):
            matrix[m][n]='-'
            n+=1
        m+=lines+1
        
    m=0+2+(lines-1)
    n=scol+2+(lines-1)
    for i in range(lines):
        m+=1
        matrix[m][n]='|'
        
    m=0
    n=scol
    for i in range(lines):
        m+=1
        matrix[m][n]='|'
        
def fun6(matrix,lines,scol):
    m=0
    n=scol+1
    
    for i in range(0,3):
        n=scol+1
        for j in range(lines):
            matrix[m][n]='-'
            n+=1
        m+=lines+1
        
    m=0+2+(lines-1)
    n=scol+2+(lines-1)
    for i in range(lines):
        m+=1
        matrix[m][n]='|'
        
    m=0
    n=scol
    for i in range(lines):
        m+=1
        matrix[m][n]='|'
        
    m=0+2+(lines-1)
    n=scol
    for i in range(lines):
        m+=1
        matrix[m][n]='|'
        
def fun7(matrix,lines,scol):
    m=0
    n=scol+1
    
    for j in range(lines):
        matrix[m][n]='-'
        n+=1
        
        
    m=0
    n=scol+2+(lines-1)
    for i in range(lines):
        m+=1
        matrix[m][n]='|'
    
    m=0+2+(lines-1)
    n=scol+2+(lines-1)
    for i in range(lines):
        m+=1
        matrix[m][n]='|'
        
def fun8(matrix,lines,scol):
    m=0
    n=scol+1
    
    for i in range(0,3):
        n=scol+1
        for j in range(lines):
            matrix[m][n]='-'
            n+=1
        m+=lines+1
        
    m=0+2+(lines-1)
    n=scol+2+(lines-1)
    for i in range(lines):
        m+=1
        matrix[m][n]='|'
        
    m=0
    n=scol
    for i in range(lines):
        m+=1
        matrix[m][n]='|'
        
    m=0
    n=scol+2+(lines-1)
    for i in range(lines):
        m+=1
        matrix[m][n]='|'
        
    m=0+2+(lines-1)
    n=scol
    for i in range(lines):
        m+=1
        matrix[m][n]='|'
    
def fun9(matrix,lines,scol):
    m=0
    n=scol+1
    
    for i in range(0,3):
        n=scol+1
        for j in range(lines):
            matrix[m][n]='-'
            n+=1
        m+=lines+1
        
    m=0+2+(lines-1)
    n=scol+2+(lines-1)
    for i in range(lines):
        m+=1
        matrix[m][n]='|'
        
    m=0
    n=scol
    for i in range(lines):
        m+=1
        matrix[m][n]='|'
        
    m=0
    n=scol+2+(lines-1)
    for i in range(lines):
        m+=1
        matrix[m][n]='|'
        
def fun0(matrix,lines,scol):
    m=0
    n=scol+1
    
    for i in range(0,2):
        n=scol+1
        for j in range(lines):
            matrix[m][n]='-'
            n+=1
        m+=2*(lines+1)
        
    m=0+2+(lines-1)
    n=scol+2+(lines-1)
    for i in range(lines):
        m+=1
        matrix[m][n]='|'
        
    m=0
    n=scol
    for i in range(lines):
        m+=1
        matrix[m][n]='|'
        
    m=0
    n=scol+2+(lines-1)
    for i in range(lines):
        m+=1
        matrix[m][n]='|'
        
    m=0+2+(lines-1)
    n=scol
    for i in range(lines):
        m+=1
        matrix[m][n]='|'
        
while(True):
    list1=input()
    list1=list1.split(' ')
    lines=int(list1[0])
    no=int(list1[1])
    
    
    if(lines==0 and no==0):
        break
        
    length=len(list1[1])

    row=5+((lines-1)*2)
    col=length*(3+(lines))
    matrix=[[' ']*col for _ in range(row)]
    
    no1=list1[1]
    scol=0
    for k in range (length):
        val=no1[k]
        
        if(val=='1'):
            fun1(matrix,lines,scol)
        elif(val=='2'):
            fun2(matrix,lines,scol)
        elif(val=='3'):
            fun3(matrix,lines,scol)
        elif(val=='4'):
            fun4(matrix,lines,scol)
        elif(val=='5'):
            fun5(matrix,lines,scol)
        elif(val=='6'):
            fun6(matrix,lines,scol)
        elif(val=='7'):
            fun7(matrix,lines,scol)
        elif(val=='8'):
            fun8(matrix,lines,scol)
        elif(val=='9'):
            fun9(matrix,lines,scol)
        elif(val=='0'):
            fun0(matrix,lines,scol)
            
        scol=scol+4+(lines-1)
        
    for i in range (row):
        for j in range (col):
            print(matrix[i][j],end='')
        print("")
    print("")
# Out:
# 2 123456789
#       --   --        --   --   --   --   --
#    |    |    | |  | |    |       | |  | |  |
#    |    |    | |  | |    |       | |  | |  |
#       --   --   --   --   --        --   --
#    | |       |    |    | |  |    | |  |    |
#    | |       |    |    | |  |    | |  |    |
#       --   --        --   --        --   --
#
# 3 12345
#        ---   ---         ---
#     |     |     | |   | |
#     |     |     | |   | |
#     |     |     | |   | |
#        ---   ---   ---   ---
#     | |         |     |     |
#     | |         |     |     |
#     | |         |     |     |
#        ---   ---         ---
#
# 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-0f4074182987> in <module>()
#     258     list1=list1.split(' ')
#     259     lines=int(list1[0])
# --> 260     no=int(list1[1])
#     261
#     262
#
# IndexError: list index out of range
